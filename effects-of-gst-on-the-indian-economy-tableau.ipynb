# %% [markdown]
# <a href="https://www.kaggle.com/code/rutwik1000/effects-of-gst-on-the-indian-economy-tableau?scriptVersionId=112812360" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Effects of GST on Indian Economy
#
# <div>
#  <img src="https://www.softwaresuggest.com/blog/wp-content/uploads/2019/04/GST-Calculator-Software_1-1068x427.png">
# </div>

# %% [markdown]
# # Content📖
# > 1. [Dataset](#1)
# > 2. [Methodology](#2)
# > 3. [Motivation](#3)
# > 4. [What is GST](#4)
# > 5. [Objectives of GST](#5)
# > 6. [Revenues Sources of Government](#6)
# > 7. [GST Slabs](#7)
# > 8. [Measures to Compare the Pre-GST and Post-GST Regime](#8)
# > 9. [Study at Union level](#9)
# > 10. [Study at State level](#10)
# > 11. [Sectorwise Study](#11)

# %% [markdown]
# # Dataset🗃️<a id="1"></a>
# > The dataset is an Consolidation of:
# > - The Data obtained from the Research papers [1](https://ideas.repec.org/p/npf/wpaper/22-385.html), [2](https://link.springer.com/article/10.1007/s40171-021-00297-3).
#
# # Methodology🛠️<a id="2"></a>
# > The methodology for compunding this dataset invovled reviewing various research papers, government reports, media blogs.Various approaches for qunatifying the impact of GST were studied and the approach put forward in the Revenue Assessment of Goods and Services Tax (GST) in India by Sacchidananda Mukherjee was selected.The performance of Indian economy before and after the introduction of GST was studied in the research paper.
#
# # Motivation💡 <a id="3"></a>
# > Motivation for creation of this dataset was to address following questions :
# > - What is GST?
# > - Why was GST introduced?
# > - How GST affected the Indian Economy?
# > - To get a Data driven perspective.

# %% [markdown]
# # What is GST <a id="4"></a>
# >- GST is known as the Goods and Services Tax.
# >- It is an indirect tax which has replaced many indirect taxes in India such as the excise duty, VAT, services tax, etc.
# >- The Goods and Service Tax Act was passed in the Parliament on 29th March 2017 and came into effect on 1st July 2017.

# %% [markdown]
# # Objectives of GST <a id="5"></a>
# The Objectives and its implementation is shown in the infographic below.
#
#
# ![GST Objectives.jpg](attachment:95436369-677c-4aad-9d59-31a5bdc0bcd7.jpg)

# %% [markdown]
# # Revenue Sources of Government <a id="6"></a>
# The Dashboard below demonstrates the earning mediums of the government:
#
# <div class='tableauPlaceholder' id='viz1670014408190' style='position: relative'><noscript><a href='#'><img alt='GST Government Revenue ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;DD&#47;DDZBQFW5S&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='path' value='shared&#47;DDZBQFW5S' /> <param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;DD&#47;DDZBQFW5S&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-US' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1670014408190');                    var vizElement = divElement.getElementsByTagName('object')[0];                    if ( divElement.offsetWidth > 800 ) { vizElement.style.width='1000px';vizElement.style.height='827px';} else if ( divElement.offsetWidth > 500 ) { vizElement.style.width='1000px';vizElement.style.height='827px';} else { vizElement.style.width='100%';vizElement.style.height='777px';}                     var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %% [markdown]
# # GST Slabs <a id="7"></a>
# The GST is sub-branched in the slabs which are given as per the graphic below :
#
# ![GST SLABS.png](attachment:34bc49d8-3a03-4704-ba61-c501cfc6f311.png)

# %% [markdown]
# # Measures to Compare the Pre-GST and Post-GST Regime <a id="8"></a>
# Not all taxes were included under GST after its introduction.The table below shows the taxes which were partially or fully excluded from the GST.
#
# ![pg6 Table.png](attachment:883767d1-8390-40aa-adbc-e40da60af61e.png)

# %% [markdown]
# # Study at Union Level <a id="9"></a>
#  **Tax Buoyancy** :
# >- Tax buoyancy highlights the relationship between the change in the government's tax revenue growth and the changes in GDP.
# >- When a tax is buoyant, it shows an increase in its revenue rate without increasing the tax rate.
# >- It is one of the key indicators to assess the efficiency of a government's tax system.
#
# **GST Compensation**
# >- It is monetary compensation to States for loss of revenue arising on account of implementation of the Goods and Services Tax for a period of five years from the date of its implementation i.e 2017-2022.
# >- A state is qualified to GST compensation if the Tax Revenue does not appreciate more 14% compared to previous fiscal year.
# >- Union Government is supposed to pay this compensation to states from the GST Cess obtained from cess levied on 28% slab(with Cess)  items.
#
# <div class='tableauPlaceholder' id='viz1670014502666' style='position: relative'><noscript><a href='#'><img alt='Dashboard 1 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Un&#47;Union_16694019379380&#47;Dashboard1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='Union_16694019379380&#47;Dashboard1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Un&#47;Union_16694019379380&#47;Dashboard1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-US' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1670014502666');                    var vizElement = divElement.getElementsByTagName('object')[0];                    if ( divElement.offsetWidth > 800 ) { vizElement.style.width='1000px';vizElement.style.height='827px';} else if ( divElement.offsetWidth > 500 ) { vizElement.style.width='1000px';vizElement.style.height='827px';} else { vizElement.style.width='100%';vizElement.style.height='727px';}                     var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %% [markdown]
# # Study at State Level <a id="10"></a>
# <div class='tableauPlaceholder' id='viz1670014547874' style='position: relative'><noscript><a href='#'><img alt='State Dashboard ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;St&#47;StatewisefromCombinedData&#47;StateDashboard&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='StatewisefromCombinedData&#47;StateDashboard' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;St&#47;StatewisefromCombinedData&#47;StateDashboard&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-US' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1670014547874');                    var vizElement = divElement.getElementsByTagName('object')[0];                    if ( divElement.offsetWidth > 800 ) { vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';} else if ( divElement.offsetWidth > 500 ) { vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';} else { vizElement.style.width='100%';vizElement.style.height='1127px';}                     var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %% [markdown]
# # Sectorwise Study <a id="11"></a>
# **GVA :**
# >- In economics, gross value added is the measure of the value of goods and services produced in an area, industry or sector of an economy.
# >- GVA is the value added to the product to enhance the various aspects of the product whereas GDP is the total amount of products produced in the country.
# >- **GVA= Gross Domestic Product + Subsidies on products – Taxes on products**
#
# **Constant Series**
# >- Constant series show the data for each year in the value of a particular base year.
# >- For example, data reported in constant 2010 prices show data for 1990, 2000, and all other years in 2010 prices.
#
# **Current Series**
# >- Current series show the data for an accounting year, as estimated at current year prices.
#
# **Constant vs Current Price Example**
# > GDP at current prices can increase even when there is no increase in the flow of goods and services in the economy, but in the price level happens to rise. In contrast, GDP at constant prices will increase only when there is an increase in the flow of goods and services in the economy.
#
# <div class='tableauPlaceholder' id='viz1670014580198' style='position: relative'><noscript><a href='#'><img alt='Dashboard 1 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Se&#47;Sectorwise_16694017506190&#47;Dashboard1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='Sectorwise_16694017506190&#47;Dashboard1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Se&#47;Sectorwise_16694017506190&#47;Dashboard1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-US' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1670014580198');                    var vizElement = divElement.getElementsByTagName('object')[0];                    if ( divElement.offsetWidth > 800 ) { vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';} else if ( divElement.offsetWidth > 500 ) { vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';} else { vizElement.style.width='100%';vizElement.style.height='977px';}                     var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
